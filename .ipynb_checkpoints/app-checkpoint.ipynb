# %% [markdown]
# ## Import Libraries

# %%
import requests
import pandas as pd
import time
from wordcloud import WordCloud
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## Import API Key

# %%
import config
api_key = config.api_key
yir_channel_id = 'UCj16_sROSTrwMSWW88fOJeg'

# %% [markdown]
# ## Make an API Call for videos

# %%
pageToken=""
url = 'https://www.googleapis.com/youtube/v3/search?key='+api_key+"&channelId="+yir_channel_id+"&part=snippet,id&order=date&maxResults=10000"+pageToken

response = requests.get(url).json()

# %% [markdown]
# ## Checking variables I should loop for

# %%
response['items']
# Out:
# [{'kind': 'youtube#searchResult',
#   'etag': 'Ax6PxyFSuicwJ56Re6WSOcs8y0Y',
#   'id': {'kind': 'youtube#video', 'videoId': '-Hqz0v_Wxz8'},
#   'snippet': {'publishedAt': '2022-01-21T09:00:00Z',
#    'channelId': 'UCj16_sROSTrwMSWW88fOJeg',
#    'title': '드디어 만났다💃 소프라노 조수미와 이루마의 찐케미 살펴보기👀｜ Cuore Indigo(꾸오레 인디고)',
#    'description': '소프라노 조수미와 작곡가 겸 피아니스트 이루마의 Cuore Indigo(꾸오레 인디고) 못다한 이야기   세계 정상의 아티스트들의 찐케미 ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/-Hqz0v_Wxz8/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/-Hqz0v_Wxz8/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/-Hqz0v_Wxz8/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'YIRUMA place / 이루마 official',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2022-01-21T09:00:00Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'i0bIg67klICYTAiD2CYq4jlzb-g',
#   'id': {'kind': 'youtube#video', 'videoId': 's5kOHKFj-rw'},
#   'snippet': {'publishedAt': '2022-01-10T10:00:32Z',
#    'channelId': 'UCj16_sROSTrwMSWW88fOJeg',
#    'title': 'Yiruma Talks About Cuore Indigo🌃',
#    'description': "Yiruma unveiled a special track called 'Cuore Indigo' collaborated with THE world's most outstanding Soprano Sumi Jo. Let's take ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/s5kOHKFj-rw/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/s5kOHKFj-rw/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/s5kOHKFj-rw/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'YIRUMA place / 이루마 official',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2022-01-10T10:00:32Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'Hzkj0X40VWBGnClDcv-NC9mRuB0',
#   'id': {'kind': 'youtube#video', 'videoId': '9jgLo8EDoBo'},
#   'snippet': {'publishedAt': '2021-12-15T11:55:30Z',
#    'channelId': 'UCj16_sROSTrwMSWW88fOJeg',
#    'title': 'Yiruma&#39;s new single teaser',
#    'description': "To Celebrate Yiruma's 20th anniversary of his debut, a special single will be out on 17 December 2021. This time, the world's most ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/9jgLo8EDoBo/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/9jgLo8EDoBo/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/9jgLo8EDoBo/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'YIRUMA place / 이루마 official',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-12-15T11:55:30Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '9biNa-KSRhacO0wEQyBMA2qsaNc',
#   'id': {'kind': 'youtube#video', 'videoId': 'pefsdnqN0Vg'},
#   'snippet': {'publishedAt': '2021-04-01T13:00:30Z',
#    'channelId': 'UCj16_sROSTrwMSWW88fOJeg',
#    'title': 'The Best of Yiruma &#39;Reminiscent&#39; Behind Storyㅣ이루마 명곡 &#39;Reminiscnet&#39; 숨겨진 이야기',
#    'description': 'Music Flows in You Ep.7 이루마가 소개하는 이루마의 [명곡 Behind] 어디에서도 듣지 못했던 이루마의 명곡 속 숨겨진 이야기들을 ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/pefsdnqN0Vg/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/pefsdnqN0Vg/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/pefsdnqN0Vg/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'YIRUMA place / 이루마 official',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-04-01T13:00:30Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'w-4k34LEJHI7QssQnpSmv20CnYU',
#   'id': {'kind': 'youtube#video', 'videoId': 'x5HwA-_4xZA'},
#   'snippet': {'publishedAt': '2021-03-19T13:00:19Z',
#    'channelId': 'UCj16_sROSTrwMSWW88fOJeg',
#    'title':
...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/nB-uow6NDgQ/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/nB-uow6NDgQ/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/nB-uow6NDgQ/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'YIRUMA place / 이루마 official',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2020-10-23T09:00:28Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'hfop8WB6ld6M3un3LMXCo9atxW8',
#   'id': {'kind': 'youtube#video', 'videoId': 'XVTepy6nVfI'},
#   'snippet': {'publishedAt': '2020-10-16T09:00:11Z',
#    'channelId': 'UCj16_sROSTrwMSWW88fOJeg',
#    'title': '[Music Flows in You #2] 이루마가 추천하는 Music~ ㅣ 1415 소개',
#    'description': '이루마 #이루마피아노 #이루마피아노모음 #이루마official #MusicFlowsinYou 이루마가 추천하는 Music~ Music Flows in You의 ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/XVTepy6nVfI/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/XVTepy6nVfI/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/XVTepy6nVfI/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'YIRUMA place / 이루마 official',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2020-10-16T09:00:11Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'a8OcC6M-tyCDCuI2Q64BAPnodGQ',
#   'id': {'kind': 'youtube#video', 'videoId': '9KjSplNvSVM'},
#   'snippet': {'publishedAt': '2020-10-11T09:00:01Z',
#    'channelId': 'UCj16_sROSTrwMSWW88fOJeg',
#    'title': '[Music Flows in You #1] 이루마가 추천하는 Music~ ㅣ New Hope Club 소개',
#    'description': '이루마 #이루마피아노 #이루마피아노모음 #이루마official #MusicFlowsinYou 이루마가 추천하는 Music~ Music Flows in You의 ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/9KjSplNvSVM/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/9KjSplNvSVM/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/9KjSplNvSVM/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'YIRUMA place / 이루마 official',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2020-10-11T09:00:01Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'zu9UzwXGOMWRGMp28fb7-1czj70',
#   'id': {'kind': 'youtube#video', 'videoId': 'Kt_mTgl2yVo'},
#   'snippet': {'publishedAt': '2020-07-31T11:00:05Z',
#    'channelId': 'UCj16_sROSTrwMSWW88fOJeg',
#    'title': 'YIRUMA Summer Best – 1 hour of YIRUMA piano',
#    'description': '이루마가 직접 선곡한 Yiruma 피아노 연속듣기 여름 베스트! 시원한 여름, 선선한 바람 같은 이루마의 힐링 피아노 연주곡 연속듣기!',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Kt_mTgl2yVo/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/Kt_mTgl2yVo/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/Kt_mTgl2yVo/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'YIRUMA place / 이루마 official',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2020-07-31T11:00:05Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'ROki4eMdr140OBA4IWatWeRN2gQ',
#   'id': {'kind': 'youtube#video', 'videoId': '5ysjbJKnsU8'},
#   'snippet': {'publishedAt': '2020-07-01T09:00:03Z',
#    'channelId': 'UCj16_sROSTrwMSWW88fOJeg',
#    'title': '[이루마 official] Room with a view 곡 소개 영상',
#    'description': '이루마 #이루마피아노 #이루마피아노모음 #이루마official New Song live play for the first time 이루마 신곡 최초 라이브!! #이루마 ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/5ysjbJKnsU8/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/5ysjbJKnsU8/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/5ysjbJKnsU8/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'YIRUMA place / 이루마 official',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2020-07-01T09:00:03Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '1GbLCja0uHfqwshWm7bRDLctHU4',
#   'id': {'kind': 'youtube#video', 'videoId': '-N4O2fm6lOA'},
#   'snippet': {'publishedAt': '2020-05-31T12:00:27Z',
#    'channelId': 'UCj16_sROSTrwMSWW88fOJeg',
#    'title': '[Yiruma official] NEW Album - Room with a view - original all songs for 1hour',
#    'description': '이루마 #이루마피아노 #이루마피아노모음 #이루마official [Yiruma official] NEW Album - Room with a view - original all songs for ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/-N4O2fm6lOA/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/-N4O2fm6lOA/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/-N4O2fm6lOA/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'YIRUMA place / 이루마 official',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2020-05-31T12:00:27Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'BXk0sQpm4yumo_4o3SkVQTl_zqw',
#   'id': {'kind': 'youtube#video', 'videoId': 'C4W4gorU3mE'},
#   'snippet': {'publishedAt': '2020-04-29T09:00:04Z',
#    'channelId': 'UCj16_sROSTrwMSWW88fOJeg',
#    'title': '이루마 신곡 최초 라이브!!',
#    'description': '이루마 #이루마피아노 #이루마피아노모음 #이루마official 이루마 신곡 최초 라이브!! 라이브 당시 포커스 문제가 있었습니다ㅠㅠ 죄송 ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi
',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/LCwacocnqd0/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/LCwacocnqd0/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/LCwacocnqd0/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'YIRUMA place / 이루마 official',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2019-09-26T02:27:47Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'rLRsPHUsGO6SXIrpJy3BpyWnnJo',
#   'id': {'kind': 'youtube#video', 'videoId': 'Hfdv4Q4oYf8'},
#   'snippet': {'publishedAt': '2019-09-25T13:26:48Z',
#    'channelId': 'UCj16_sROSTrwMSWW88fOJeg',
#    'title': '2019/09/25 yiruma place live',
#    'description': '',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Hfdv4Q4oYf8/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/Hfdv4Q4oYf8/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/Hfdv4Q4oYf8/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'YIRUMA place / 이루마 official',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2019-09-25T13:26:48Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'alKOLdfNpydiBNFSknpJaEQ_RUo',
#   'id': {'kind': 'youtube#video', 'videoId': 'wkCYIz4vroc'},
#   'snippet': {'publishedAt': '2019-09-18T13:52:20Z',
#    'channelId': 'UCj16_sROSTrwMSWW88fOJeg',
#    'title': '2019/09/18 yiruma place Live',
#    'description': '',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/wkCYIz4vroc/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/wkCYIz4vroc/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/wkCYIz4vroc/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'YIRUMA place / 이루마 official',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2019-09-18T13:52:20Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'i-AVMMv1zW9X4PJykeuCWaUuDZI',
#   'id': {'kind': 'youtube#video', 'videoId': 'rWZoAee_H6g'},
#   'snippet': {'publishedAt': '2019-09-04T13:27:00Z',
#    'channelId': 'UCj16_sROSTrwMSWW88fOJeg',
#    'title': '유튜브 라이브 | 귀를 사로잡는 코드 활용법 by 이루마',
#    'description': '',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/rWZoAee_H6g/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/rWZoAee_H6g/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/rWZoAee_H6g/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'YIRUMA place / 이루마 official',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2019-09-04T13:27:00Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '-0Quw_z7HWnPVeYd5GenX0IfgQ0',
#   'id': {'kind': 'youtube#video', 'videoId': 'VXjx0j0GgeI'},
#   'snippet': {'publishedAt': '2019-08-30T06:07:25Z',
#    'channelId': 'UCj16_sROSTrwMSWW88fOJeg',
#    'title': '유튜브 라이브 | 이번엔 River Flows in You 특강!! By 이루마',
#    'description': '이번 영상에서는 Kiss the rain 과 함께 많이 사랑받는 곡인 River Flows in You (너의 마음속엔 강이 흐른다) 에 대한 이야기를 해보려 ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/VXjx0j0GgeI/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/VXjx0j0GgeI/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/VXjx0j0GgeI/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'YIRUMA place / 이루마 official',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2019-08-30T06:07:25Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'FoGeU3o5wQ3BnZDGkRf2NnLhfoc',
#   'id': {'kind': 'youtube#video', 'videoId': 'X0R4WPNoPZo'},
#   'snippet': {'publishedAt': '2019-08-22T11:00:53Z',
#    'channelId': 'UCj16_sROSTrwMSWW88fOJeg',
#    'title': '브이로그 | 이루마의 뮤직 플레이스를 소개합니다!',
#    'description': '오늘은 제가 음악작업하는 공간을 소개해드리려 합니다! 저의 음악이 탄생하는 공간이자 요즘에는 여러분과 유튜브 라이브로 소통 ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/X0R4WPNoPZo/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/X0R4WPNoPZo/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/X0R4WPNoPZo/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'YIRUMA place / 이루마 official',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2019-08-22T11:00:53Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '0zSEjA-keLZ3v-bZri2z1AHiNDE',
#   'id': {'kind': 'youtube#video', 'videoId': 'w3OFIHMxlQo'},
#   'snippet': {'publishedAt': '2019-08-19T16:47:18Z',
#    'channelId': 'UCj16_sROSTrwMSWW88fOJeg',
#    'title': '유튜브 라이브 | 이루마의 골든 유튜브^^ 신청곡 받습니다. (feat. 라이온 킹)',
#    'description': '앞으로는 여러분과 좀더 다양한 음악을 나눠보려 합니다. 그 첫번째 시작으로 이번에 인상깊게 봤던 라이온킹 영화의 O.S.T 음악을 ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/w3OFIHMxlQo/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/w3OFIHMxlQo/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/w3OFIHMxlQo/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'YIRUMA place / 이루마 official',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2019-08-19T16:47:18Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'lEkLCNskhImjLlBZzwKs1rBpZgg',
#   'id': {'kind': 'youtube#video', 'videoId': 'FpH152FuSwo'},
#   'snippet': {'publishedAt': '2019-08-14T13:44:40Z',
#    'channelId': 'UCj16_sROSTrwMSWW88fOJeg',
#    'title': '유튜브 라이브 | 이루마가 직접 전해주는 &quot;키스더레인&quot; 의 모든것?!',
#    'description': '많은분들이 "키스더레인" 이곡을 많이 사랑해주시고 자신만의 스타일로 많이 연주해주셔서 너무 감사하고 행복합니다! 저만의 "키스더 ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/FpH152FuSwo/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/FpH152FuSwo/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/FpH152FuSwo/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'YIRUMA place / 이루마 official',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2019-08-14T13:44:40Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'emPuTQ2hpzi1cvAVxlS4q3mfcD0',
#   'id': {'kind': 'youtube#video', 'videoId': 'XmdxX6Jc0_Q'},
#   'snippet': {'publishedAt': '2019-08-14T12:56:48Z',
#    'channelId': 'UCj16_sROSTrwMSWW88fOJeg',
#    'title': 'At MindTailor Studio 14/Aug',
#    'description': '',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/XmdxX6Jc0_Q/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/XmdxX6Jc0_Q/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/XmdxX6Jc0_Q/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'YIRUMA place / 이루마 official',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2019-08-14T12:56:48Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'Gjx623U9iWSUq31966BTIZVVjHE',
#   'id': {'kind': 'youtube#video', 'videoId': 'gHbffKptoYI'},
#   'snippet': {'publishedAt': '2019-08-02T06:08:12Z',
#    'channelId': 'UCj16_sROSTrwMSWW88fOJeg',
#    'title': '2019 이태리 콘서트 &quot;이루마 in Indigo&quot; |  2019년 8월 9일',
#    'description': '',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/gHbffKptoYI/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/gHbffKptoYI/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/gHbffKptoYI/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'YIRUMA place / 이루마 official',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2019-08-02T06:08:12Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'inikDmJE5s7_n16pF77Mv3y9NnA',
#   'id': {'kind': 'youtube#video', 'videoId': 'pCmTvUX1lhI'},
#   'snippet': {'publishedAt': '2019-08-02T04:13:50Z',
#    'channelId': 'UCj16_sROSTrwMSWW88fOJeg',
#    'title': '유튜브 라이브 | Q&amp;A 1편 - 피아노 초보 연주자를 위한 팁?',
#    'description': '앞으로 라이브 방송에서 제 음악에 대한 여러 비하인드 스토리나 연주 팁 등도 함께 공유해드릴 예정입니다^^! 질문도 많이 올려주시고 ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/pCmTvUX1lhI/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/pCmTvUX1lhI/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/pCmTvUX1lhI/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'YIRUMA place / 이루마 official',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2019-08-02T04:13:50Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'iCc7r54DVsFQkcKriTPLYkdXRb0',
#   'id': {'kind': 'youtube#video', 'videoId': 'HQeiNHTsrnY'},
#   'snippet': {'publishedAt': '2019-07-24T10:27:15Z',
#    'channelId': 'UCj16_sROSTrwMSWW88fOJeg',
#    'title': '유튜브 라이브 | 안녕하세요! 이루마의 라방입니다^^',
#    'description': '드디어 유튜브 라이브 방송으로 만나뵙게 되었네요. 앞으로 공연이나 녹음 일정이 없는 수요일 저녁 9시 (한국시간) 에는 여기 "이루마 ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/HQeiNHTsrnY/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/HQeiNHTsrnY/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/HQeiNHTsrnY/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'YIRUMA place / 이루마 official',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2019-07-24T10:27:15Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'Mnp54loXuqKs8QnlKMKzv90oyW4',
#   'id': {'kind': 'youtube#video', 'videoId': 'UaPkQ5VNuS4'},
#   'snippet': {'publishedAt': '2019-07-23T10:51:29Z',
#    'channelId': 'UCj16_sROSTrwMSWW88fOJeg',
#    'title': '공연이야기 | 2019 &#39;시드니 오페라하우스 단독 콘서트&#39; 무대 뒷이야기',
#    'description': '2016년과 17년 시드니 오페라하우스 대극장 전석매진으로 성공적인 호주 공연을 마친 후, 2019년 5월 한번 더 전석 유료매진을 기록 ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/UaPkQ5VNuS4/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/UaPkQ5VNuS4/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/UaPkQ5VNuS4/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'YIRUMA place / 이루마 official',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2019-07-23T10:51:29Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'x3CtafxOrTbl5ySkjDJ-Di3uRNU',
#   'id': {'kind': 'youtube#playlist',
#    'playlistId': 'PLNxt60uwHOpWtvSnznLABojoCVMtodf53'},
#   'snippet': {'publishedAt': '2019-07-18T19:23:29Z',
#    'channelId': 'UCj16_sROSTrwMSWW88fOJeg',
#    'title': '너의 연주 | 당신의 이루마는?',
#    'description': '당신 삶의 배경음악이 되고싶은 저희 꿈을 이뤄주는, 나를 연주해주는 당신... 감사합니다.',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/9JOPw-NL2AA/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/9JOPw-NL2AA/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/9JOPw-NL2AA/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'YIRUMA place / 이루마 official',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2019-07-18T19:23:29Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'cp4MEu7nSlSnRYW9SKGn7Tdo648',
#   'id': {'kind': 'youtube#playlist',
#    'playlistId': 'PLNxt60uwHOpUvyw_NPs76La1pBgbHEQQg'},
#   'snippet': {'publishedAt': '2019-07-18T18:33:04Z',
#    'channelId': 'UCj16_sROSTrwMSWW88fOJeg',
#    'title': '유튜브 라이브 | 이루마의 수요라이브',
#    'description': '매주 수요일 저녁 9시. 저와 함께 하는 유튜브 라이브 방송.',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/AFInThRaCgk/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/AFInThRaCgk/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/AFInThRaCgk/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'YIRUMA place / 이루마 official',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2019-07-18T18:33:04Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'd0VvEtQYvMhE8lr1mzEMTLby39M',
#   'id': {'kind': 'youtube#playlist',
#    'playlistId': 'PLNxt60uwHOpU9-OcqP50lii2W_1tMEy10'},
#   'snippet': {'publishedAt': '2019-07-18T18:23:30Z',
#    'channelId': 'UCj16_sROSTrwMSWW88fOJeg',
#    'title': '뮤직비디오 | Music Video',
#    'description': '',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/3ILFt0QbeMM/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/3ILFt0QbeMM/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/3ILFt0QbeMM/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'YIRUMA place / 이루마 official',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2019-07-18T18:23:30Z'}}]

# %%
response['items'][0]['id']['videoId']
# Out:
# '-Hqz0v_Wxz8'

# %% [markdown]
# ## Making the dataframe and loading the data

# %%
df = pd.DataFrame(columns=['comment'])

# %%
# Making for loop to get video id
for video in response['items']:
    if video['id']['kind'] == "youtube#video":
        video_id = video['id']['videoId']
        
        # Collecting the comments from all videos
        url_comment = 'https://www.googleapis.com/youtube/v3/commentThreads?key='+api_key+"&videoId="+video_id+"&part=snippet&maxResults=10000"+pageToken
        response_comment = requests.get(url_comment).json()
        
        for comment in response_comment['items']:
            comments = comment['snippet']['topLevelComment']['snippet']['textDisplay']
            
            df = df.append({'comment': comments}, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13432\1889963661.py in <module>
#       8         response_comment = requests.get(url_comment).json()
#       9
# ---> 10         for comment in response_comment['items']:
#      11             comments = comment['snippet']['topLevelComment']['snippet']['textDisplay']
#      12
#
# KeyError: 'items'

# %%
print(df)
# Out:
#                                                 comment
# 0                                    Mampir blora abang
# 1                                             왜이렇게 잘생기심
# 2     안녕하세요. s.j레몬트리입니다. 먼저 잘 못된 정보를 시청자님께 알려 드린 점 진...
# 3             Sehat selalu bang, kiss the rain mu keren
# 4                      와 영상 재밌게 보고 갑니다 너무 좋다 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# ...                                                 ...
# 2905                                              멋져요😭😭
# 2906  from Canada! Thank you for playing in Vancouve...
# 2907                                       Yaasssss!!!!
# 2908  Hiiiiii my favorite musician~~ comment from Ch...
# 2909   초대해 주셔서 감사해요 :)  아, 그리고 yeah~~~에 효과음을 넣으십시다 ㅋㅋㅋㅋ
#
# [2910 rows x 1 columns]

# %% [markdown]
# ## Fun part -- making the wordcloud

# %%
up_words = '' 

#looping through all incidents and joining them to one text, to extract most common words
for arg in df["comment"]: 

    tokens = arg.split()  
      
    up_words += " ".join(tokens)+" "

wordcloud = WordCloud(width = 700, height = 700, 
                background_color ='white', 
                min_font_size = 10).generate(up_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (5, 5), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()
